# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import time
salaries = pd.read_csv('/Users/josephhartono/Downloads/nba_files/salaries_1985to2018.csv')
players = pd.read_csv('/Users/josephhartono/Downloads/nba_files/players.csv')
merged = pd.merge(left=salaries, right=players, left_on='player_id', right_on='_id')
# print(type(merged))
# display(merged)

# %%
def getString_range(rangeLength):
    list_of_lists = []
    ordinalList = []
    rangeVal = rangeLength

    for n in range(1,rangeVal):
        if(n == 11):
            ordinalList.append(str(n) + "th overall")
        elif(n == 12):
            ordinalList.append(str(n) + "th overall")
        elif(n == 13):
            ordinalList.append(str(n) + "th overall")        
        elif((n % 10) == 1):
            ordinalList.append(str(n) + "st overall")
        elif((n % 10) == 2):
            ordinalList.append(str(n) + "nd overall")
        elif((n % 10) == 3):
            ordinalList.append(str(n) + "rd overall")
        else:
            ordinalList.append(str(n) + "th overall")
            
    list_of_lists.append(ordinalList)
    #print(ordinalList)

    rangeList = []
    for n in range(1, rangeVal):
        rangeList.append(str(n))
    list_of_lists.append(rangeList)

    #print(rangeList)
    return list_of_lists

# %%
list = getString_range(100)
merged['draft_pick'] = merged['draft_pick'].replace(list[0], list[1])

# %%
def getSalary(year):
    
    time.sleep(1)
    
    yearString = str(year)
    year5 = year + 4
    from nba_api.stats.endpoints import drafthistory
    data = drafthistory.DraftHistory("00").get_data_frames()[0]
    data = data[data['SEASON'] == yearString]

    salaries2000 = merged[merged['draft_year'] == yearString]
    salaries2000 = salaries2000[salaries2000['season_start'] == year5]



    please = salaries2000['draft_pick'] = salaries2000['draft_pick'].astype(int)

    please = salaries2000.sort_values(by='draft_pick', ascending=True)
    
    return please
# Out:
#       league  player_id   salary   season  season_end  season_start  \
# 8044     NBA  martike01  9454546  2004-05        2005          2004
# 12192    NBA  swiftst01  5993105  2004-05        2005          2004
# 8571     NBA  milesda01  6750000  2004-05        2005          2004
# 4124     NBA  fizerma01   735960  2004-05        2005          2004
# 8639     NBA  millemi01  6000000  2004-05        2005          2004
# 6534     NBA  johnsde03   745046  2004-05        2005          2004
# 8548     NBA   mihmch01  3371393  2004-05        2005          2004
# 2724     NBA  crawfja01  5760000  2004-05        2005          2004
# 10387    NBA  przybjo01  1500000  2004-05        2005          2004
# 3388     NBA  doolike01   745046  2004-05        2005          2004
# 8813     NBA  moisoje01  1760000  2004-05        2005          2004
# 12342    NBA  thomaet01  4903000  2004-05        2005          2004
# 172      NBA  alexaco02    79029  2004-05        2005          2004
# 2464     NBA  cleavma01   735960  2004-05        2005          2004
# 2518     NBA  collija02  1500000  2004-05        2005          2004
# 12685    NBA  turkohe01  4903000  2004-05        2005          2004
# 8103     NBA  masonde01  6529630  2004-05        2005          2004
# 10693    NBA  richaqu01  5800000  2004-05        2005          2004
# 7820     NBA  magloja01  8533333  2004-05        2005          2004
# 2455     NBA  claxtsp01  3300000  2004-05        2005          2004
# 10028    NBA  petermo01  4400000  2004-05        2005          2004
# 11961    NBA  stevede01  2500000  2004-05        2005          2004
# 12642    NBA  tsakaja01  2900000  2004-05        2005          2004
# 9124     NBA  ndiayma02   750000  2004-05        2005          2004
# 8639             Mitchell, South Dakota  ...           5   1st round
# 6534   Washington, District of Columbia  ...           6   1st round
# 8548               Milwaukee, Wisconsin  ...           7   1st round
# 2724                Seattle, Washington  ...           8   1st round
# 10387             Monticello, Minnesota  ...           9   1st round
# 3388            Ft. Lauderdale, Florida  ...          10   1st round
# 8813                      Paris, France  ...          11   1st round
# 12342                  Harlem, New York  ...          12   1st round
# 172             Bridgeport, Connecticut  ...          13   1st round
# 2464                    Flint, Michigan  ...          14   1st round
# 2518                  Springfield, Ohio  ...          15   1st round
# 12685                  Istanbul, Turkey  ...          16   1st round
# 8103                  Waxahachie, Texas  ...          17   1st round
# 10693                 Chicago, Illinois  ...          18   1st round
# 7820                    Toronto, Canada  ...          19   1st round
# 2455                   Queens, New York  ...          20   1st round
# 10028                   Flint, Michigan  ...          21   1st round
# 11961                Fresno, California  ...          23   1st round
# 12642                  Rustavi, Georgia  ...          25   1st round
# 9124                     Dakar, Senegal  ...          26   1st round
# 1591                 Postojna, Slovenia  ...          27   1st round
# 7796           Walnut Creek, California  ...          29   1st round
# 6350                   Belgrade, Serbia  ...          30   2nd round
# 12932                   Tulsa, Oklahoma  ...          33   2nd round
# 5850               Berkeley, California  ...          37   2nd round
# 5849               Berkeley, California  ...          37   2nd round
# 9143                     Meoqui, Mexico  ...          38   2nd round
# 10536                    Columbus, Ohio  ...          43   2nd round
# 2096                   Tolono, Illinois  ...          44   2nd round
# 11668                  Atlanta, Georgia  ...          45   2nd round
# 5372            Los Angeles, California  ...          49   2nd round
# 3303                   Denver, Colorado  ...          50   2nd round
#
#                  draft_team draft_year  height  \
# 8044        New Jersey Nets       2000     6-9
# 12192   Vancouver Grizzlies       2000     6-9
# 8571   Los Angeles Clippers       2000     6-9
# 4124          Chicago Bulls       2000     6-9
# 8639          Orlando Magic       2000     6-8
# 6534          Atlanta Hawks       2000     6-9
# 8548          Chicago Bulls       2000     7-0
# 2724    Cleveland Cavaliers       2000     6-5
# 10387       Houston Rockets       2000     7-1
# 3388          Orlando Magic       2000     6-3
# 8813         Boston Celtics       2000    6-10
# 12342      Dallas Mavericks       2000     6-9
# 172           Orlando Magic       2000     6-5
# 2464        Detroit Pistons       2000     6-2
# 2518        Milwaukee Bucks       2000     7-0
# 12685      Sacramento Kings       2000    6-10
# 8103    Seattle SuperSonics       2000     6-7
# 10693  Los Angeles Clippers       2000     6-6
# 7820      Charlotte Hornets       2000    6-11
# 2455     Philadelphia 76ers       2000    5-11
# 10028       Toronto Raptors       2000     6-7
# 11961             Utah Jazz       2000     6-5
# 12642          Phoenix Suns       2000     7-2
# 9124         Denver Nuggets       2000     7-0
# 1591         Indiana Pacers       2000     7-2
# 7796     Los Angeles Lakers       2000     6-9
# 6350   Los Angeles Clippers       2000     6-7
# 12932         Chicago Bulls       2000    6-11
# 5850             Miami Heat       2000     6-1
# 5849             Miami Heat       2000     6-1
# 9143        Houston Rockets       2000     6-8
# 10536       Milwaukee Bucks       2000     6-6
# 2096        Detroit Pistons       2000     6-8
# 11668      Sacramento Kings       2000    6-11
# 10693                  Shooting Guard and Small Forward  Right  223lb
# 7820                                             Center  Right  259lb
# 2455                                        Point Guard  Right  166lb
# 10028                  Small Forward and Shooting Guard   Left  218lb
# 11961                  Small Forward and Shooting Guard  Right  210lb
# 12642                                            Center  Right  285lb
# 9124                                             Center  Right  255lb
# 1591                                             Center  Right  252lb
# 7796                           Center and Power Forward  Right  240lb
# 6350   Shooting Guard and Small Forward and Point Guard  Right  198lb
# 12932                                            Center  Right  245lb
# 5850                     Shooting Guard and Point Guard  Right  180lb
# 5849                     Shooting Guard and Point Guard  Right  180lb
# 9143                    Power Forward and Small Forward  Right  240lb
# 10536                  Shooting Guard and Small Forward   Left  220lb
# 2096                    Power Forward and Small Forward  Right  245lb
# 11668                          Center and Power Forward  Right  250lb
# 5372                                        Point Guard  Right  185lb
# 3303                    Small Forward and Power Forward  Right  215lb
#
# [36 rows x 31 columns]

# %%
plt.clf()
Dict = {}

fig = plt.figure(figsize = (10, 5))
ax = fig.add_subplot(111)

for num in range(22):
    

    
    dataSheet = getSalary(1995 + num)
    
    max = 0
    
    for sal in dataSheet['salary']:
        if sal > max:
            max = sal
    
    #print(max)
    
    normal_sal = []
    
    
    
    for sal in dataSheet['salary']:
        normal_sal.append(sal/max)
    #print(normal_sal)
        
    dataSheet['normalized_salaries'] = normal_sal

    
    #plt.scatter(dataSheet['draft_pick'], dataSheet['normalized_salaries'], marker='^')
    
    
    draft_picks = dataSheet['draft_pick']
    count = 1 

    temp_data = pd.DataFrame(columns=["NBA", "id", "salary", "2004-05", "2005", "2004", "Denver Nuggets", "id_", "December 30, 1977", "Saginaw, Michigan", "AST", "FG%", "FG%3", "FT%", "carG", "carP", "carPt", "carTR","carW","carEF", "college", "draft_pick", "draftR", "draftT", "draftY", "height" ,"hs", "name", "pos", "shoo", "weight"])

    for x in draft_picks:
        if(x != count):
            

            temp_data.loc[len(temp_data)] = ["NBA", "id", "0", "2004-05", "2005", "2004", "Denver Nuggets", "id_", "December 30, 1977", "Saginaw, Michigan", "AST", "FG%", "FG%3", "FT%", "carG", "carP", "carPt", "carTR","carW","carEF", "college", count, "draftR", "draftT", "draftY", "height" ,"hs", "name", "pos", "shoo", "weight"]

            count = x
            
            
            if Dict.get(count) is not None:
                Dict[count] = Dict[count] + 1
            else:
                Dict[count] = 1
            
            
            
            count = count + 1
        else:
            count = count + 1
    #display(two)
    #print(type(temp_data['salary']))
    #salary = temp_data['salary'] / max
    #plt.scatter(  temp_data['draft_pick'], temp_data['salary'], marker='x',color='r')
    #ax.scatter(  dataSheet['draft_pick'], dataSheet['salary'], marker='o', color ='g')

    




ax.bar(Dict.keys(), Dict.values(), color = 'r', width = 0.6, alpha=0.5)

    
plt.tick_params(axis='both', which='major', labelsize=8)
plt.xlim([-2, 62])
plt.ylim([-0.2, 12])
#plt.ylim([-0.05, 1.05])
plt.ylabel("# of Players that did not Re-sign within 4 Years of Play")
plt.xlabel('Overall Draft Pick')
plt.title('# of Players Dropped for each Draft Pick (1995 - 2017)')
plt.legend()
plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
