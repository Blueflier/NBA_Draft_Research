# %%
import numpy as np
import pandas as pd
df = pd.read_csv('nm_sal_yr_pos_gp_min_ovr_ya_nS.csv',index_col = [0])
df = df[df['yearsAfter'] == 4]

# %%
xx = []
yy = []

for ovr in range(1,61):

    df1 = df[df['overall'] == ovr]

    if df1.empty:
        xx.append(0)
        yy.append(0)

    else:
        df1 = df1['norm_sal'].values
        xx.append(df1.mean())
        if len(df1) < 2:
            yy.append(0.0001)
        else:
            yy.append(df1.std())
# display(len(xx) , len(yy))
display(len(xx) , len(yy))
XX = np.array(xx)
YY = np.array(yy)

ex = sum(YY)/60
ey = sum(XX)/60
display(ex/ey)

display(sum(YY)/60)
display(sum(XX)/60)
# Out:
# 60
# 60
# 0.6085296601812874
# 0.11393022228603979
# 0.18722213515788003

# %%
import matplotlib.pyplot as plt
from matplotlib.pyplot import cm

plt.clf()
ax = plt.figure(dpi=300,figsize=(8,4)).add_subplot()
x = np.arange(0.0, 60.0, 1)
ax.errorbar(x, xx, yy, alpha = 0.9,ls='none',c='lightgreen',marker = '*')
ax.plot(x,xx,c='black')

    
ax.set_xlim(-1, 60)
ax.set_ylim(-0.1, 0.7)
ax.tick_params(axis='x', labelsize=17)
ax.tick_params(axis='y', labelsize=17)

ax.grid()
#ax.legend(['Drafted Season', 'Second Season', 'Third Season'])
#plt.legend(loc="upper left", bbox_to_anchor=(1.2,1.0))

#     plt.savefig('SixteenPie.png')
plt.savefig('NormSal vs OVR.png')
plt.show()
#5th year salary average vs draft pick
#x-axis is draft pick
#y-axis is normalzied salary to max
