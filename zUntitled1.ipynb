# %%
from nba_api.stats.endpoints import leaguegamelog

df = leaguegamelog.LeagueGameLog(direction = 'ASC', league_id = '00',
player_or_team_abbreviation = 'T',
season = '2012',
season_type_all_star = 'Regular Season' ,
sorter = 'DATE').get_data_frames()[0]

display(df)
# Out:
#      SEASON_ID     TEAM_ID TEAM_ABBREVIATION            TEAM_NAME     GAME_ID  \
# 0        22012  1610612747               LAL   Los Angeles Lakers  0021200003
# 1        22012  1610612742               DAL     Dallas Mavericks  0021200003
# 2        22012  1610612764               WAS   Washington Wizards  0021200001
# 3        22012  1610612739               CLE  Cleveland Cavaliers  0021200001
# 4        22012  1610612738               BOS       Boston Celtics  0021200002
# ...        ...         ...               ...                  ...         ...
# 2455     22012  1610612749               MIL      Milwaukee Bucks  0021201226
# 2456     22012  1610612763               MEM    Memphis Grizzlies  0021201223
# 2457     22012  1610612762               UTA            Utah Jazz  0021201223
# 2458     22012  1610612766               CHA    Charlotte Bobcats  0021201219
# 2459     22012  1610612739               CLE  Cleveland Cavaliers  0021201219
#
# ...

# %%
from nba_api.stats.endpoints import teamyearbyyearstats

df = teamyearbyyearstats.TeamYearByYearStats(league_id = '00',
per_mode_simple = 'PerGame',
season_type_all_star = 'Regular Season' ,
team_id = 1610612746).get_data_frames()[0]

display(df)
# Out:
#        TEAM_ID    TEAM_CITY TEAM_NAME     YEAR  GP  WINS  LOSSES  WIN_PCT  \
# 0   1610612746      Buffalo    Braves  1970-71  82    22      60    0.268
# 1   1610612746      Buffalo    Braves  1971-72  82    22      60    0.268
# 2   1610612746      Buffalo    Braves  1972-73  82    21      61    0.256
# 3   1610612746      Buffalo    Braves  1973-74  82    42      40    0.512
# 4   1610612746      Buffalo    Braves  1974-75  82    49      33    0.598
# 5   1610612746      Buffalo    Braves  1975-76  82    46      36    0.561
# 6   1610612746      Buffalo    Braves  1976-77  82    30      52    0.366
# 7   1610612746      Buffalo    Braves  1977-78  82    27      55    0.329
# 8   1610612746    San Diego  Clippers  1978-79  82    43      39    0.524
# 9   1610612746    San Diego  Clippers  1979-80  82    35      47    0.427
# 10  1610612746    San Diego  Clippers  1980-81  82    36      46    0.439
# 11  1610612746    San Diego  Clippers  1981-82  82    17      65    0.207
# ...

# %%
import numpy as np
import pandas as pd

joseph = pd.read_csv('/Users/Tim/Documents/GitHub/NBA-Draft-Biola-Summer-Research/finished_joseph_csv_manual_pie - joseph_csv_manual_pie.csv')

#current_df = pd.concat([joseph, tim], ignore_index=True)
display(joseph)
# Out:
#      PLAYER_ID FIRST_NAME_x LAST_NAME_x      PLAYER_NAME_x POSITION_x  \
# 0         2037        Jamal    Crawford     Jamal Crawford      PG-SG
# 1         2084        Chris      Porter       Chris Porter      SF-PF
# 2         2217      Brendan     Haywood    Brendan Haywood          C
# 3         2210      Richard   Jefferson  Richard Jefferson         SF
# 4         2207          Joe     Johnson        Joe Johnson      SF-SG
# ..         ...          ...         ...                ...        ...
# 194     202696       Nikola     Vucevic     Nikola Vucevic       PF-C
# 195     202689        Kemba      Walker       Kemba Walker         PG
# 196     202682      Derrick    Williams   Derrick Williams      PF-SF
# 197     203112       Quincy         Acy         Quincy Acy         PF
# 198     203084     Harrison      Barnes    Harrison Barnes      SF-SG
#
#      HEIGHT_WO_SHOES HEIGHT_WO_SHOES_FT_IN  WEIGHT  WINGSPAN WINGSPAN_FT_IN  \
# ...

# %%
tim = pd.read_csv('/Users/Tim/Documents/GitHub/NBA-Draft-Biola-Summer-Research/tim_csv_manual_pie.csv', sep='\t')
display(tim)
current_df = pd.concat([joseph, tim], ignore_index=True)
display(current_df)
current_df.to_csv('draft_nba_data_2000_2016_w_PIE_cells.csv', index=False)
# Out:
#      PLAYER_ID FIRST_NAME_x LAST_NAME_x      PLAYER_NAME_x POSITION_x  \
# 0       203115         Will      Barton        Will Barton      SG-SF
# 1       203078      Bradley        Beal       Bradley Beal         SG
# 2       203733      William      Buford     William Buford      SG-SF
# 3       203109          Jae     Crowder        Jae Crowder         SF
# 4       203099        Jared  Cunningham   Jared Cunningham      SG-PG
# ..         ...          ...         ...                ...        ...
# 194    1627756       Denzel   Valentine   Denzel Valentine      SG-SF
# 195    1627785       Isaiah   Whitehead   Isaiah Whitehead      PG-SG
# 196    1627786         Troy    Williams      Troy Williams         SF
# 197    1627787         Kyle     Wiltjer       Kyle Wiltjer         PF
# 198    1627757      Stephen   Zimmerman  Stephen Zimmerman          C
#
#      HEIGHT_WO_SHOES HEIGHT_WO_SHOES_FT_IN  WEIGHT  WINGSPAN WINGSPAN_FT_IN  \
# ...
