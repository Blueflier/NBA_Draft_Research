# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv('finished_joseph_csv_manual_pie.csv')
data
# Out:
#      PLAYER_ID FIRST_NAME_x LAST_NAME_x      PLAYER_NAME_x POSITION_x  \
# 0         2037        Jamal    Crawford     Jamal Crawford      PG-SG
# 1         2084        Chris      Porter       Chris Porter      SF-PF
# 2         2217      Brendan     Haywood    Brendan Haywood          C
# 3         2210      Richard   Jefferson  Richard Jefferson         SF
# 4         2207          Joe     Johnson        Joe Johnson      SF-SG
# ..         ...          ...         ...                ...        ...
# 194     202696       Nikola     Vucevic     Nikola Vucevic       PF-C
# 195     202689        Kemba      Walker       Kemba Walker         PG
# 196     202682      Derrick    Williams   Derrick Williams      PF-SF
# 197     203112       Quincy         Acy         Quincy Acy         PF
# 198     203084     Harrison      Barnes    Harrison Barnes      SF-SG
#
#      HEIGHT_WO_SHOES HEIGHT_WO_SHOES_FT_IN  WEIGHT  WINGSPAN WINGSPAN_FT_IN  \
# ...

# %%
import pandas as pd

df = pd.read_csv('/Users/josephhartono/Documents/GitHub/NBA-Draft-Biola-Summer-Research/draft_nba_data_2000_2016_w_PIE_and_salaries_and college_stats.csv')

pla = df[df['PLAYER_ID'] == 2207]
pla['MIN']
# Out:
# 4    29.1
# Name: MIN, dtype: float64

# %%
for col in df.columns:
    print(col)
# Out:
# PLAYER_ID
# FIRST_NAME_x
# LAST_NAME_x
# PLAYER_NAME_x
# POSITION_x
# HEIGHT_WO_SHOES
# HEIGHT_WO_SHOES_FT_IN
# WEIGHT
# WINGSPAN
# WINGSPAN_FT_IN
# STANDING_REACH
# STANDING_REACH_FT_IN
# DRAFT_CLASS
# SEASON_ID
# LEAGUE_ID
# ORGANIZATION_ID
# SCHOOL_NAME
# PLAYER_AGE
# GP
# GS
# MIN
# FGM
# FGA
# FG_PCT
# FG3M
# FG3A
# FG3_PCT
# FTM
# FTA
# FT_PCT
# OREB
# DREB
# REB
# AST
# STL
# BLK
# TOV
# PF
# PTS
# PIE_5_YR
# 5th_YR_SALARY
# 5th_YR_SALARY_TAG
